# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in c:\users\romina\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied, skipping upgrade: scikit-learn in c:\users\romina\anaconda3\lib\site-packages (from sklearn) (0.22.1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\romina\anaconda3\lib\site-packages (from scikit-learn->sklearn) (0.14.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.0 in c:\users\romina\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.14.5)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in c:\users\romina\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.2.1)

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\romina\anaconda3\lib\site-packages (0.14.1)

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.utils import to_categorical
from keras.layers import Dense
from sklearn.preprocessing import LabelEncoder
from keras.callbacks import EarlyStopping
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
print(df.shape)
df.head()
# Out:
# (6991, 41)
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1     ...      koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520     ...                 -81      4.467           0.064
# 1          0.000581     ...                -176      4.544           0.044
# 2          0.000115     ...                -174      4.564           0.053
# 3          0.001130     ...                -211      4.438           0.070
# 4          0.001900     ...                -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
# Remove Space for `FALSE POSITIVE` category
mask = df["koi_disposition"] == "FALSE POSITIVE"
df.loc[mask, "koi_disposition"] = "False_Positive"
df["koi_disposition"][0:5]
# Out:
# 0         CONFIRMED
# 1    False_Positive
# 2    False_Positive
# 3         CONFIRMED
# 4         CONFIRMED
# Name: koi_disposition, dtype: object

# %%
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  False_Positive              0              1              0              0
# 2  False_Positive              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1     ...      koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520     ...                 -81      4.467           0.064
# 1          0.000581     ...                -176      4.544           0.044
# 2          0.000115     ...                -174      4.564           0.053
# 3          0.001130     ...                -211      4.438           0.070
# 4          0.001900     ...                -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
X = df.iloc[:, 1:42]
print(X.shape)
X.head()
# Out:
# (6991, 40)
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
#
#    koi_time0bk_err2     ...      koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0         -0.003520     ...                 -81      4.467           0.064
# 1         -0.000581     ...                -176      4.544           0.044
# 2         -0.000115     ...                -174      4.564           0.053
# 3         -0.001130     ...                -211      4.438           0.070
# 4         -0.001900     ...                -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 40 columns]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
from sklearn.model_selection import train_test_split

y = df.iloc[:, 0]

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
from sklearn.preprocessing import MinMaxScaler
X_scaler = MinMaxScaler().fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)
y_train_categorical.shape
# Out:
# (5243, 3)

# %% [markdown]
# # Train the Model

# %%
model = Sequential()
model.add(Dense(units=100, activation='relu', input_dim=40))
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=3, activation='softmax'))
# Out:
# WARNING:tensorflow:From C:\Users\Romina\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Romina\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\Romina\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\Romina\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\Romina\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 100)               4100
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 14,503
# Trainable params: 14,503
# Non-trainable params: 0
# _________________________________________________________________

# %%
callbacks = [EarlyStopping(monitor='val_loss', patience=2)]
model.fit(
    X_train_scaled,
    y_train_categorical,
    callbacks=callbacks,
    epochs=60,
    shuffle=True,
    verbose=2
)
# Out:
# WARNING:tensorflow:From C:\Users\Romina\Anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/60
#  - 1s - loss: 0.5546 - acc: 0.7299
# Epoch 2/60
# C:\Users\Romina\Anaconda3\lib\site-packages\keras\callbacks.py:569: RuntimeWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,acc
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
#  - 0s - loss: 0.3686 - acc: 0.8133
# Epoch 3/60
#  - 0s - loss: 0.3507 - acc: 0.8243
# Epoch 4/60
#  - 0s - loss: 0.3450 - acc: 0.8219
# Epoch 5/60
#  - 0s - loss: 0.3339 - acc: 0.8360
# Epoch 6/60
#  - 1s - loss: 0.3253 - acc: 0.8398
# Epoch 7/60
#  - 0s - loss: 0.3249 - acc: 0.8419
# Epoch 8/60
#  - 0s - loss: 0.3192 - acc: 0.8503
# Epoch 9/60
#  - 0s - loss: 0.3146 - acc: 0.8510
# Epoch 10/60
#  - 1s - loss: 0.3100 - acc: 0.8552
# Epoch 11/60
#  - 0s - loss: 0.3108 - acc: 0.8510
# Epoch 12/60
#  - 0s - loss: 0.2996 - acc: 0.8604
# Epoch 13/60
#  - 0s - loss: 0.2985 - acc: 0.8705
# Epoch 14/60
#  - 0s - loss: 0.2962 - acc: 0.8644
# Epoch 15/60
#  - 0s - loss: 0.2982 - acc: 0.8632
# Epoch 16/60
#  - 0s - loss: 0.2858 - acc: 0.8724
# Epoch 17/60
#  - 1s - loss: 0.2875 - acc: 0.8716
# Epoch 18/60
#  - 0s - loss: 0.2855 - acc: 0.8737
# Epoch 19/60
#  - 0s - loss: 0.2840 - acc: 0.8705
# Epoch 20/60
#  - 1s - loss: 0.2821 - acc: 0.8693
# Epoch 21/60
#  - 0s - loss: 0.2827 - acc: 0.8663
# Epoch 22/60
#  - 0s - loss: 0.2865 - acc: 0.8688
# Epoch 23/60
#  - 0s - loss: 0.2817 - acc: 0.8726
# Epoch 24/60
#  - 0s - loss: 0.2874 - acc: 0.8699
# Epoch 25/60
#  - 0s - loss: 0.2774 - acc: 0.8779
# Epoch 26/60
#  - 0s - loss: 0.2784 - acc: 0.8756
# Epoch 27/60
#  - 1s - loss: 0.2691 - acc: 0.8829
# Epoch 28/60
#  - 0s - loss: 0.2727 - acc: 0.8798
# Epoch 29/60
#  - 0s - loss: 0.2684 - acc: 0.8829
# Epoch 30/60
#  - 1s - loss: 0.2743 - acc: 0.8777
# Epoch 31/60
#  - 0s - loss: 0.2756 - acc: 0.8783
# Epoch 32/60
#  - 1s - loss: 0.2645 - acc: 0.8829
# Epoch 33/60
#  - 1s - loss: 0.2646 - acc: 0.8821
# Epoch 34/60
#  - 0s - loss: 0.2598 - acc: 0.8856
# Epoch 35/60
#  - 0s - loss: 0.2585 - acc: 0.8892
# Epoch 36/60
#  - 1s - loss: 0.2603 - acc: 0.8880
# Epoch 37/60
#  - 0s - loss: 0.2648 - acc: 0.8802
# Epoch 38/60
#  - 0s - loss: 0.2573 - acc: 0.8880
# Epoch 39/60
#  - 0s - loss: 0.2557 - acc: 0.8873
# Epoch 40/60
#  - 1s - loss: 0.2682 - acc: 0.8766
# Epoch 41/60
#  - 0s - loss: 0.2560 - acc: 0.8898
# Epoch 42/60
#  - 0s - loss: 0.2542 - acc: 0.8869
# Epoch 43/60
#  - 1s - loss: 0.2534 - acc: 0.8911
# Epoch 44/60
#  - 0s - loss: 0.2517 - acc: 0.8892
# Epoch 45/60
#  - 1s - loss: 0.2515 - acc: 0.8896
# Epoch 46/60
#  - 0s - loss: 0.2476 - acc: 0.8907
# Epoch 47/60
#  - 0s - loss: 0.2530 - acc: 0.8888
# Epoch 48/60
#  - 0s - loss: 0.2524 - acc: 0.8899
# Epoch 49/60
#  - 0s - loss: 0.2450 - acc: 0.8909
# Epoch 50/60
#  - 0s - loss: 0.2445 - acc: 0.8917
# Epoch 51/60
#  - 0s - loss: 0.2421 - acc: 0.8926
# Epoch 52/60
#  - 0s - loss: 0.2455 - acc: 0.8940
# Epoch 53/60
#  - 0s - loss: 0.2444 - acc: 0.8932
# Epoch 54/60
#  - 0s - loss: 0.2467 - acc: 0.8884
# Epoch 55/60
#  - 0s - loss: 0.2413 - acc: 0.8959
# Epoch 56/60
#  - 0s - loss: 0.2421 - acc: 0.8945
# Epoch 57/60
#  - 0s - loss: 0.2443 - acc: 0.8901
# Epoch 58/60
#  - 1s - loss: 0.2407 - acc: 0.8955
# Epoch 59/60
#  - 0s - loss: 0.2443 - acc: 0.8920
# Epoch 60/60
#  - 0s - loss: 0.2385 - acc: 0.8932

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Normal Neural Network - Loss: 0.26907908329974595, Accuracy: 0.8810068649885584

# %%
encoded_predictions = model.predict_classes(X_test_scaled)
prediction_labels = label_encoder.inverse_transform(encoded_predictions)

outputdf = pd.DataFrame({"Prediction": prediction_labels, "Actual": y_test.ravel()}).reset_index(drop=True)
outputdf
# Out:
#           Prediction          Actual
# 0     False_Positive  False_Positive
# 1          CANDIDATE       CANDIDATE
# 2     False_Positive  False_Positive
# 3     False_Positive  False_Positive
# 4     False_Positive  False_Positive
# 5          CONFIRMED       CONFIRMED
# 6          CONFIRMED       CANDIDATE
# 7          CANDIDATE       CANDIDATE
# 8          CANDIDATE       CANDIDATE
# 9     False_Positive  False_Positive
# 10         CONFIRMED       CONFIRMED
# 11         CONFIRMED       CONFIRMED
# 12         CONFIRMED       CONFIRMED
# 13    False_Positive  False_Positive
# 14         CANDIDATE       CANDIDATE
# 15         CANDIDATE       CANDIDATE
# 16    False_Positive  False_Positive
# 17    False_Positive  False_Positive
# 18         CANDIDATE       CONFIRMED
# 19         CANDIDATE       CONFIRMED
# 20         CONFIRMED       CONFIRMED
# 21         CONFIRMED       CANDIDATE
# 22         CONFIRMED       CONFIRMED
# 23         CANDIDATE       CANDIDATE
# 24         CANDIDATE       CANDIDATE
# 25         CANDIDATE       CONFIRMED
# 26         CANDIDATE       CANDIDATE
# 27         CONFIRMED       CONFIRMED
# 28         CANDIDATE       CANDIDATE
# 29         CANDIDATE       CANDIDATE
# ...              ...             ...
# 1718       CONFIRMED       CONFIRMED
# 1719  False_Positive  False_Positive
# 1720       CANDIDATE       CANDIDATE
# 1721  False_Positive  False_Positive
# 1722  False_Positive  False_Positive
# 1723  False_Positive  False_Positive
# 1724       CONFIRMED       CONFIRMED
# 1725       CANDIDATE       CANDIDATE
# 1726  False_Positive  False_Positive
# 1727       CANDIDATE       CANDIDATE
# 1728       CONFIRMED       CONFIRMED
# 1729  False_Positive  False_Positive
# 1730       CANDIDATE       CONFIRMED
# 1731       CONFIRMED       CANDIDATE
# 1732  False_Positive  False_Positive
# 1733  False_Positive  False_Positive
# 1734  False_Positive  False_Positive
# 1735  False_Positive  False_Positive
# 1736  False_Positive  False_Positive
# 1737  False_Positive  False_Positive
# 1738  False_Positive  False_Positive
# 1739       CANDIDATE       CANDIDATE
# 1740  False_Positive  False_Positive
# 1741  False_Positive  False_Positive
# 1742  False_Positive  False_Positive
# 1743       CANDIDATE       CANDIDATE
# 1744       CANDIDATE       CANDIDATE
# 1745       CANDIDATE       CONFIRMED
# 1746       CANDIDATE       CONFIRMED
# 1747       CANDIDATE       CONFIRMED
#
# [1748 rows x 2 columns]

# %%
outputdf[outputdf.Prediction != outputdf.Actual]
# Out:
#           Prediction          Actual
# 6          CONFIRMED       CANDIDATE
# 18         CANDIDATE       CONFIRMED
# 19         CANDIDATE       CONFIRMED
# 21         CONFIRMED       CANDIDATE
# 25         CANDIDATE       CONFIRMED
# 40         CANDIDATE       CONFIRMED
# 41         CONFIRMED       CANDIDATE
# 47         CANDIDATE       CONFIRMED
# 52         CANDIDATE       CONFIRMED
# 56         CANDIDATE       CONFIRMED
# 57         CANDIDATE       CONFIRMED
# 73         CANDIDATE       CONFIRMED
# 80         CONFIRMED       CANDIDATE
# 86         CANDIDATE       CONFIRMED
# 88         CANDIDATE       CONFIRMED
# 89         CONFIRMED       CANDIDATE
# 107        CANDIDATE       CONFIRMED
# 108        CANDIDATE       CONFIRMED
# 110        CONFIRMED       CANDIDATE
# 119        CONFIRMED       CANDIDATE
# 129        CANDIDATE       CONFIRMED
# 135        CANDIDATE       CONFIRMED
# 136        CANDIDATE       CONFIRMED
# 143        CONFIRMED       CANDIDATE
# 165   False_Positive       CANDIDATE
# 178        CONFIRMED       CANDIDATE
# 186        CANDIDATE       CONFIRMED
# 204        CONFIRMED       CANDIDATE
# 215        CONFIRMED       CANDIDATE
# 225   False_Positive       CANDIDATE
# ...              ...             ...
# 1465       CANDIDATE       CONFIRMED
# 1468       CONFIRMED       CANDIDATE
# 1472       CANDIDATE       CONFIRMED
# 1477       CANDIDATE       CONFIRMED
# 1494       CONFIRMED       CANDIDATE
# 1498       CANDIDATE       CONFIRMED
# 1500       CONFIRMED       CANDIDATE
# 1501       CANDIDATE       CONFIRMED
# 1505       CONFIRMED       CANDIDATE
# 1557       CANDIDATE       CONFIRMED
# 1564       CONFIRMED       CANDIDATE
# 1574       CANDIDATE       CONFIRMED
# 1576       CONFIRMED       CANDIDATE
# 1582       CANDIDATE       CONFIRMED
# 1583       CONFIRMED       CANDIDATE
# 1593       CONFIRMED       CANDIDATE
# 1626       CONFIRMED       CANDIDATE
# 1647       CONFIRMED       CANDIDATE
# 1652       CANDIDATE       CONFIRMED
# 1669       CANDIDATE       CONFIRMED
# 1672       CANDIDATE       CONFIRMED
# 1681       CANDIDATE       CONFIRMED
# 1693       CANDIDATE       CONFIRMED
# 1704       CONFIRMED       CANDIDATE
# 1707       CANDIDATE  False_Positive
# 1730       CANDIDATE       CONFIRMED
# 1731       CONFIRMED       CANDIDATE
# 1745       CANDIDATE       CONFIRMED
# 1746       CANDIDATE       CONFIRMED
# 1747       CANDIDATE       CONFIRMED
#
# [208 rows x 2 columns]

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'deeplearning.sav'
joblib.dump(model, filename)
# Out:
# ['deeplearning.sav']
